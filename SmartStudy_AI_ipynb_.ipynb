# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan12375/smartstudy-planner/blob/main/SmartStudy_AI_ipynb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf *

# %%
# ==========================================
# SMARTSTUDY MASTER LAUNCHER
# ==========================================
import os
import subprocess
import urllib.request
import time

print("🛠️ Setting up environment...")
REPO_URL = "https://github.com/aryan12375/smartstudy-planner"

# Clone the repository
if not os.path.exists('manage.py'):
    # !git clone {REPO_URL} temp_repo
    # !cp -r temp_repo/* .
    # !cp -r temp_repo/.* .
    # !rm -rf temp_repo

# Install Python and Node dependencies
if os.path.exists('requirements.txt'):
    # !sed -i '/threejs-requirements/d' requirements.txt
    # !pip install -q -r requirements.txt
    # !npm install -q -g localtunnel

# 🚨 FIX: Override Django's ALLOWED_HOSTS so it accepts the cloud tunnel URL
if os.path.exists('smartstudy/settings.py'):
    with open('smartstudy/settings.py', 'a') as f:
        f.write("\n# Added by Colab Launcher\nALLOWED_HOSTS = ['*']\n")

print("📦 Running database migrations...")
# !python manage.py migrate > /dev/null

print("\n🚀 Starting SmartStudy Django Server...")
# Start Django server in the background
subprocess.Popen(["python", "manage.py", "runserver", "8000"])
time.sleep(3)

# Fetch the external IP for the Localtunnel security bypass
external_ip = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip()

print("\n" + "="*50)
print("🔐 IMPORTANT: You will be asked for an 'Endpoint IP'.")
print(f"👉 COPY THIS EXACT IP: {external_ip}")
print("="*50 + "\n")

print("✨ SMARTSTUDY LIVE AT THE URL BELOW:")
# !npx localtunnel --port 8000
# Out:
# 🛠️ Setting up environment...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 21.3 MB/s eta 0:00:00
# ⠙⠹⠸⠼⠴⠦
# changed 22 packages in 826ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦📦 Running database migrations...
#
# 🚀 Starting SmartStudy Django Server...
#
# ...
# 🔐 IMPORTANT: You will be asked for an 'Endpoint IP'.
# 👉 COPY THIS EXACT IP: 35.194.131.135
# ...
#
# ✨ SMARTSTUDY LIVE AT THE URL BELOW:
# ⠙⠹⠸⠼⠴⠦your url is: https://bitter-items-judge.loca.lt
